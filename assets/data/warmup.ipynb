# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import load_digits
# %matplotlib inline

# %% [markdown]
# # 1 - Dataset

# %%
from sklearn.datasets import load_digits

digits = load_digits()
data = digits.data
target = digits.target

# %% [markdown]
# # 2 - SVM sur les données (+ validation non-croisée)

# %%
from sklearn.svm import SVC
svc = SVC()
X = data
y = target
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.2, random_state=0)
svc.fit(X_train, y_train)
print(svc.score(X_train, y_train) , svc.score(X_test, y_test))
# Out:
# 0.9944328462073765 0.9916666666666667

# %%
pass
"""for img in data[:10]:
    rshp = img.reshape(8,8)
    plt.figure()
    plt.imshow(rshp, cmap='Greys')"""
# Out:
# "for img in data[:10]:\n    rshp = img.reshape(8,8)\n    plt.figure()\n    plt.imshow(rshp, cmap='Greys')"

# %% [markdown]
# # 3-4 - Validation croisée + GridSearch

# %%
from sklearn.model_selection import ShuffleSplit, cross_val_score
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
print(cross_val_score(svc, X, y, cv=cv))
# Out:
# [0.98611111 0.98611111 0.98888889 0.99444444 0.98611111]

# %%
C_range = np.logspace(-2, 2, 4)
gamma_range = np.logspace(-9, 3, 4)
param_grid = dict(gamma=gamma_range, C=C_range)
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
grid = GridSearchCV(SVC(), param_grid=param_grid, cv=cv)
#grid.fit(X, y)

print(
    "The best parameters are %s with a score of %0.2f"
    % (grid.best_params_, grid.best_score_)
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_8199/3370781898.py in <module>
#       8 print(
#       9     "The best parameters are %s with a score of %0.2f"
# ---> 10     % (grid.best_params_, grid.best_score_)
#      11 )
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %% [markdown]
# # 5 - Lire un dossier et son contenu

# %%
! ls .
data_dir = "coil-20-proc"
# Out:
# coil-20-proc	enonce.aux  enonce.out	       enonce.tex  project.ipynb
# coil-20-unproc	enonce.log  enonce.synctex.gz  output.csv  warmup.ipynb

# %%
! ls coil-20-proc
# Out:
# obj10__0.png   obj13__4.png   obj17__13.png  obj2__0.png   obj6__0.png
# obj10__10.png  obj13__50.png  obj17__14.png  obj2__10.png  obj6__10.png
# obj10__11.png  obj13__51.png  obj17__15.png  obj2__11.png  obj6__11.png
# obj10__12.png  obj13__52.png  obj17__16.png  obj2__12.png  obj6__12.png
# obj10__13.png  obj13__53.png  obj17__17.png  obj2__13.png  obj6__13.png
# obj10__14.png  obj13__54.png  obj17__18.png  obj2__14.png  obj6__14.png
# obj10__15.png  obj13__55.png  obj17__19.png  obj2__15.png  obj6__15.png
# obj10__16.png  obj13__56.png  obj1__71.png   obj2__16.png  obj6__16.png
# obj10__17.png  obj13__57.png  obj17__1.png   obj2__17.png  obj6__17.png
# obj10__18.png  obj13__58.png  obj17__20.png  obj2__18.png  obj6__18.png
# obj10__19.png  obj13__59.png  obj17__21.png  obj2__19.png  obj6__19.png
# obj10__1.png   obj1__35.png   obj17__22.png  obj2__1.png   obj6__1.png
# obj10__20.png  obj13__5.png   obj17__23.png  obj2__20.png  obj6__20.png
# ...

# %%
import os
with os.scandir(data_dir) as it:
    for entry in it:
        if not entry.name.startswith('.') and entry.is_file():
            print(entry.path, entry.name)
# Out:
# coil-20-proc/obj10__23.png obj10__23.png
# coil-20-proc/obj6__16.png obj6__16.png
# coil-20-proc/obj10__30.png obj10__30.png
# coil-20-proc/obj9__4.png obj9__4.png
# coil-20-proc/obj12__65.png obj12__65.png
# coil-20-proc/obj8__70.png obj8__70.png
# coil-20-proc/obj18__64.png obj18__64.png
# coil-20-proc/obj18__45.png obj18__45.png
# coil-20-proc/obj8__10.png obj8__10.png
# coil-20-proc/obj6__69.png obj6__69.png
# coil-20-proc/obj4__1.png obj4__1.png
# coil-20-proc/obj15__17.png obj15__17.png
# coil-20-proc/obj2__46.png obj2__46.png
# coil-20-proc/obj5__20.png obj5__20.png
# coil-20-proc/obj19__51.png obj19__51.png
# coil-20-proc/obj3__34.png obj3__34.png
# coil-20-proc/obj4__69.png obj4__69.png
# coil-20-proc/obj17__63.png obj17__63.png
# coil-20-proc/obj20__3.png obj20__3.png
# coil-20-proc/obj18__3.png obj18__3.png
# coil-20-proc/obj8__28.png obj8__28.png
# coil-20-proc/obj5__60.png obj5__60.png
# coil-20-proc/obj20__2.png obj20__2.png
# coil-20-proc/obj20__22.png obj20__22.png
# ...

# %%
import glob
fps = glob.glob(os.path.join(data_dir, "*.png"),recursive=True)
for fp in fps: print(fp)
# Out:
# coil-20-proc/obj10__23.png
# coil-20-proc/obj6__16.png
# coil-20-proc/obj10__30.png
# coil-20-proc/obj9__4.png
# coil-20-proc/obj12__65.png
# coil-20-proc/obj8__70.png
# coil-20-proc/obj18__64.png
# coil-20-proc/obj18__45.png
# coil-20-proc/obj8__10.png
# coil-20-proc/obj6__69.png
# coil-20-proc/obj4__1.png
# coil-20-proc/obj15__17.png
# coil-20-proc/obj2__46.png
# coil-20-proc/obj5__20.png
# coil-20-proc/obj19__51.png
# coil-20-proc/obj3__34.png
# coil-20-proc/obj4__69.png
# coil-20-proc/obj17__63.png
# coil-20-proc/obj20__3.png
# coil-20-proc/obj18__3.png
# coil-20-proc/obj8__28.png
# coil-20-proc/obj5__60.png
# coil-20-proc/obj20__2.png
# coil-20-proc/obj20__22.png
# coil-20-proc/obj3__37.png
# coil-20-proc/obj8__45.png
# coil-20-proc/obj9__18.png
# coil-20-proc/obj19__35.png
# coil-20-proc/obj11__29.png
# coil-20-proc/obj16__68.png
# coil-20-proc/obj10__67.png
# coil-20-proc/obj17__37.png
# coil-20-proc/obj2__53.png
# coil-20-proc/obj7__67.png
# coil-20-proc/obj7__36.png
# ...

# %%
data_dir = "/home/util/Documents/test_velocity/drum_dataset/Velvetone/close/"
! ls "/home/util/Documents/test_velocity/drum_dataset/Velvetone/close/"
print(25* "#")
print("Cas sans parcours récurssif")
fps = glob.glob(os.path.join(data_dir, "**/*.wav"),recursive=False)
for fp in fps: print(fp)
print("liste vide ?", fps == [])
print(25* "#")
print("Cas avec parcours récurssif")

fps = glob.glob(os.path.join(data_dir, "**/*.wav"),recursive=True)
for fp in fps: print(fp)
# Out:
#  Kick   Snare  'Tom 10'  'Tom 12'  'Tom 14'  'Tom 16'
# #########################
# Cas sans parcours récurssif
# liste vide ? True
# #########################
# Cas avec parcours récurssif
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/Kick 52_02_6.wav
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/Kick 52_02_4.wav
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/Kick 91_02_5.wav
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/Kick 91_02_8.wav
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/Kick 52_02_5.wav
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/Kick 91_02_4.wav
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/SubKick_02_1.wav
# ...

# %%
data_dir = "/home/util/Documents/test_velocity/drum_dataset/Velvetone/close/"
! ls "/home/util/Documents/test_velocity/drum_dataset/Velvetone/close/"
print(25* "#")
with os.scandir(data_dir) as it:
    for entry in it:
        if not entry.name.startswith('.') and entry.is_file():
            print(entry.path, entry.name)
print(25* "#")
for root, dirs, files in os.walk(data_dir, topdown=False):
   for name in files:
      print(os.path.join(root, name))
   for name in dirs:
      print(os.path.join(root, name))
# Out:
#  Kick   Snare  'Tom 10'  'Tom 12'  'Tom 14'  'Tom 16'
# #########################
# #########################
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/Kick 52_02_6.wav
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/Kick 52_02_4.wav
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/Kick 91_02_5.wav
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/Kick 91_02_8.wav
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/Kick 52_02_5.wav
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/Kick 91_02_4.wav
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/SubKick_02_1.wav
# /home/util/Documents/test_velocity/drum_dataset/Velvetone/close/Kick/Felt Beater/Regular/pp/Kick 52_02_8.wav
# ...
